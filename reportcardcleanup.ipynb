# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "./Resources/CPS School_Progress_Reports_SY1819.csv"
progress_df = pd.read_csv(csv_file)
progress_df.head()
# Out:
#    School_ID             Short_Name  \
# 0     400116   MONTESSORI ENGLEWOOD
# 1     400115       CATALYST - MARIA
# 2     400056  NOBLE - ROWE CLARK HS
# 3     610588             RICHARDSON
# 4     610548                   STEM
#
#                                      Long_Name   School_Type Primary_Category  \
# 0   The Montessori School of Englewood Charter       Charter               ES
# 1              Catalyst - Maria Charter School       Charter               ES
# 2  Noble - Rowe-Clark Math and Science Academy       Charter               HS
# 3           Robert J. Richardson Middle School  Neighborhood               MS
# 4                          STEM Magnet Academy        Magnet               ES
#
#                  Address     City     State    Zip         Phone  ...  \
# 0   6936 S HERMITAGE AVE  Chicago  Illinois  60636  7.735359e+09  ...
# 1  6727 S CALIFORNIA AVE  Chicago  Illinois  60629  7.739932e+09  ...
# ...

# %%
progress_df = progress_df [["School_ID", "Short_Name", "School_Type", "Primary_Category"]]
progress_df
# Out:
#      School_ID             Short_Name   School_Type Primary_Category
# 0       400116   MONTESSORI ENGLEWOOD       Charter               ES
# 1       400115       CATALYST - MARIA       Charter               ES
# 2       400056  NOBLE - ROWE CLARK HS       Charter               HS
# 3       610588             RICHARDSON  Neighborhood               MS
# 4       610548                   STEM        Magnet               ES
# ..         ...                    ...           ...              ...
# 649     609704            FARRAGUT HS  Neighborhood               HS
# 650     609829              BURROUGHS  Neighborhood               ES
# 651     610094            NETTELHORST  Neighborhood               ES
# 652     609722              MANLEY HS  Neighborhood               HS
# 653     610157                 SAWYER  Neighborhood               ES
#
# [654 rows x 4 columns]

# %%
progress_df.to_csv("reportcard_df.csv")
